# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   
import seaborn as sns
import comet_ml

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %% [markdown]
# ### Loading Data From From The csv File

# %%
#load data from csv file
df = pd.read_csv("EPL_20_21.csv")

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %% [markdown]
# ### performing eda

# %%
#perfrom eda for this data
df.describe() #perfrom eda for this data
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %% [markdown]
# ### EDA

# %%
#perfrom eda for this data
df.isnull().sum() #perfrom eda for this data
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %% [markdown]
# ### Removing the null values from the data

# %%
#remove the null values from the data
df = df.dropna() #remove the null values from the data

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
df.isnull().sum() #perfrom eda for this data
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %% [markdown]
# ### Nationalty of the players

# %%
#nationalty of the players
df['Nationality'].value_counts()
# Out:
# Nationality
# ENG    192
# FRA     31
# BRA     27
# ESP     26
# IRL     21
# POR     21
# SCO     20
# NED     16
# WAL     12
# BEL     11
# GER      9
# ARG      8
# CIV      8
# NGA      7
# USA      6
# DEN      6
# SUI      6
# SEN      5
# EGY      5
# ITA      5
# POL      5
# SWE      5
# GHA      5
# COL      5
# NIR      5
# TUR      5
# AUS      4
# SRB      4
# NOR      3
# ISL      3
# ALG      3
# JAM      3
# CZE      3
# GAB      2
# SVK      2
# MLI      2
# COD      2
# PAR      2
# JPN      2
# RSA      2
# CMR      2
# CRO      2
# UKR      2
# MAR      2
# ZIM      1
# MTN      1
# NZL      1
# IRN      1
# CAN      1
# MEX      1
# BFA      1
# AUT      1
# MKD      1
# BIH      1
# URU      1
# GUI      1
# GRE      1
# KOR      1
# SKN      1
# Name: count, dtype: int64

# %% [markdown]
# ### Top 10 nationalities of the players

# %%
#top 10 nationalities of the players
df['Nationality'].value_counts().head(10)
#top 10 nationalities of the players
# Out:
# Nationality
# ENG    192
# FRA     31
# BRA     27
# ESP     26
# IRL     21
# POR     21
# SCO     20
# NED     16
# WAL     12
# BEL     11
# Name: count, dtype: int64

# %% [markdown]
# ### Using seaborn to plot the top 10 nationalities of the players

# %%
#using seaborn to plot the top 10 nationalities of the players
sns.barplot(x=df['Nationality'].value_counts().head(10).index, y=df['Nationality'].value_counts().head(10).values,palette='RdGy_r')
plt.title('Top 10 Nationalities of the Players')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.show()
#using seaborn to plot the top 10 nationalities of the players

# %% [markdown]
# ### The positions of the players

# %%
#the positions of the players
df['Position'].value_counts()
#the positions of the players
# Out:
# Position
# DF       178
# MF       108
# FW        81
# FW,MF     47
# GK        42
# MF,FW     36
# DF,MF     15
# MF,DF     13
# FW,DF      6
# DF,FW      6
# Name: count, dtype: int64

# %% [markdown]
# ### Using seaorn to plot the top 10 positions of the players

# %%
#using seaorn to plot the top 10 positions of the players
sns.barplot(x=df['Position'].value_counts().head(10).index, y=df['Position'].value_counts().head(10).values,palette= 'viridis')
plt.title('Top 10 Positions of the Players')
plt.xlabel('Position')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Age of the players

# %%
#age of the players
df['Age'].value_counts()
#age of the players
# Out:
# Age
# 26    47
# 28    46
# 23    44
# 22    40
# 27    40
# 24    39
# 25    39
# 29    35
# 20    34
# 30    29
# 31    24
# 21    24
# 19    20
# 32    17
# 33    16
# 18    12
# 17     8
# 34     5
# 35     5
# 16     4
# 36     2
# 38     1
# 37     1
# Name: count, dtype: int64

# %% [markdown]
# ### Using seaborn to plot the age of the players

# %%
#using seaborn to plot the age of the players
sns.barplot(x=df['Age'].value_counts().head(10).index, y=df['Age'].value_counts().head(10).values,palette= 'summer')
plt.title('Age of the Players')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
#using seaborn to plot the age of the players

# %% [markdown]
# ### What is the oldest player  age in the dataset

# %%
#what is the oldest player in the dataset
df['Age'].max()
# Out:
# 38

# %% [markdown]
# ### Name of the oldest player in the dataset

# %%
#name of the oldest player in the dataset
df[df['Age']==df['Age'].max()]
#showing the name, age and club
df[df['Age']==df['Age'].max()][['Name', 'Age', 'Club']]
# Out:
#                Name  Age     Club
# 22  Willy Caballero   38  Chelsea

# %% [markdown]
# ### What is the name of the yongest player in the dataset

# %%
#what is the name of the yongest player in the dataset
df[df['Age']==df['Age'].min()]
#showing their clubs and age with name
df[df['Age']==df['Age'].min()][['Name', 'Club', 'Age']]
# Out:
#                    Name               Club  Age
# 76      Shola Shoretire  Manchester United   16
# 182       Dane Scarlett  Tottenham Hotspur   16
# 284  Carney Chukwuemeka        Aston Villa   16
# 530   Antwoine Hackford   Sheffield United   16

# %% [markdown]
# ### What was the higest goal(s) scored in the dataset

# %%
#who scored the most goals  in the dataset
df['Goals'].max()
#who scored the most goals  in the dataset
# Out:
# 23

# %% [markdown]
# ### Name of the player  who scored the most goals  in the dataset

# %%
#name of the player  who scored the most goals  in  the dataset
df[df['Goals']==df['Goals'].max()]
#showing the name and club and goals
df[df['Goals']==df['Goals'].max()][['Name','Club','Goals']]
# Out:
#            Name               Club  Goals
# 162  Harry Kane  Tottenham Hotspur     23

# %% [markdown]
# ### How many penalty goal was awarded in the dataset

# %%
#how many penalty goal was awarded in the dataset
df['Penalty_Goals'].sum()
# Out:
# 102

# %% [markdown]
# ### Name of top 5 players with assist

# %%
df[['Assists','Name']].sort_values(ascending=False,by='Assists',ignore_index=True)[:5]
# Out:
#    Assists             Name
# 0       14       Harry Kane
# 1       12  Kevin De Bruyne
# 2       12  Bruno Fernandes
# 3       10    Jack Grealish
# 4       10    Son Heung-min

# %% [markdown]
# ### ploting a graph of the top 5 players with the most assists

# %%
#plot a graph of the top 5 players with the most assists
df[['Assists','Name']].sort_values(ascending=False,by='Assists',ignore_index=True)[:5].plot(kind='bar',figsize=(10,5),x='Name')
plt.title('Top 5 Players with the Most Assists')
plt.xlabel('Player')
plt.ylabel('Assists')
plt.show()
#putting the names at the x axis

# %% [markdown]
# ### Who scored higest penalty goals in the dataset

# %%
#who scored higest penalty goals in the dataset
df[['Penalty_Goals',"Name","Club"]].sort_values(ascending=False,by='Penalty_Goals')[:1]
# Out:
#     Penalty_Goals             Name               Club
# 51              9  Bruno Fernandes  Manchester United

# %% [markdown]
# ### Higest goal scorer in each club showing the name and club with goals

# %%
#higest goal scorer in each club showing the name and club with goals
df[['Goals',"Name","Club"]].sort_values(ascending=False,by=['Goals']).groupby('Club').head(1)
# Out:
#      Goals                   Name                     Club
# 162     23             Harry Kane        Tottenham Hotspur
# 81      22          Mohamed Salah             Liverpool FC
# 51      18        Bruno Fernandes        Manchester United
# 214     17        Patrick Bamford             Leeds United
# 237     16  Dominic Calvert-Lewin                  Everton
# 110     15            Jamie Vardy           Leicester City
# 267     14          Ollie Watkins              Aston Villa
# 33      13         İlkay Gündoğan          Manchester City
# 191     13    Alexandre Lacazette                  Arsenal
# 428     12             Chris Wood                  Burnley
# 374     12             Danny Ings              Southampton
# 292     12          Callum Wilson         Newcastle United
# 344     11          Wilfried Zaha           Crystal Palace
# 478     11        Matheus Pereira     West Bromwich Albion
# 143     10        Michail Antonio          West Ham United
# ...

# %% [markdown]
# ### using seaborn to plot the higest goal scorer in each club showing the name and club with goals

# %%
#using seaborn to plot the higest goal scorer in each club showing the name and club with goals
sns.barplot(x=df['Club'].value_counts().index, y=df['Club'].value_counts().values,palette= 'summer')
plt.xticks(rotation=90)
plt.figure(figsize=(10,5))

#increase the size of the plot

# %%
df.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %% [markdown]
# ###  Get the names each club highest goal scorer

# %%
# get the names each club highest goal scorer
df[["Name","Club",'Goals']].sort_values(ascending=False,by=['Goals'],ignore_index=True).groupby('Club').head(1)
# Out:
#                      Name                     Club  Goals
# 0              Harry Kane        Tottenham Hotspur     23
# 1           Mohamed Salah             Liverpool FC     22
# 2         Bruno Fernandes        Manchester United     18
# 3         Patrick Bamford             Leeds United     17
# 5   Dominic Calvert-Lewin                  Everton     16
# 6             Jamie Vardy           Leicester City     15
# 7           Ollie Watkins              Aston Villa     14
# 8          İlkay Gündoğan          Manchester City     13
# 9     Alexandre Lacazette                  Arsenal     13
# 10             Chris Wood                  Burnley     12
# 11             Danny Ings              Southampton     12
# 13          Callum Wilson         Newcastle United     12
# 17          Wilfried Zaha           Crystal Palace     11
# 18        Matheus Pereira     West Bromwich Albion     11
# 23        Michail Antonio          West Ham United     10
# ...

# %% [markdown]
# ### ploting a graph of the top 5 clubs with the most goals

# %%
#plot a graph of the top 5 clubs with the most goals
df[["Club",'Goals']].sort_values(ascending=False,by=['Goals'],ignore_index=True).head(5).plot(kind='bar',figsize=(10,5),x="Club")
#Showin the top 5
plt.title('Top 5 Clubs with the Most Goals')
plt.xlabel('Club')
plt.ylabel('Goals')
plt.show()
